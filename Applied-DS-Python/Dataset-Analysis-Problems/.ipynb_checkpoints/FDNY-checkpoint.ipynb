# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# <h3>You have been provided with a dataset for the fire department of New York City.</h3>
# </br>
# <div>
#   <h4>Analyze the dataset using Pandas to determine:</h4>
#   <ol>
# <li>The total number of fire department facilities in New York city</li>
# <li>The number of fire department facilities in each borough</li>
# <li>The names of facilities in Manhattan</li>
#    </ol>

# %%
# Import the necessary libraries and check the working directory

import pandas as pd
import os 
import warnings
warnings.filterwarnings('ignore')

os.getcwd() #
os.chdir('/Users/laythal-shblawi/Desktop/Post-Graduate-Data-Science/Applied-DS-Python/Dataset-Analysis-Problems/Datasets')

# %%
# Read the dataset from csv file fire department of New York City (FDNC)

df_fdnc = pd.read_csv('FDNY.csv')

# %%
#View the content of the data 

df_fdnc.describe
# Out:
# <bound method NDFrame.describe of                                           FacilityName  \
# 0                                         FacilityName
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# ...

# %%
# View the first five records

df_fdnc.head()
# Out:
#                                         FacilityName       FacilityAddress  \
# 0                                       FacilityName       FacilityAddress
# 1                                 Engine 4/Ladder 15       42 South Street
# 2                                Engine 10/Ladder 10    124 Liberty Street
# 3                                           Engine 6     49 Beekman Street
# 4  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...  100-104 Duane Street
#
#      Borough
# 0    Borough
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
# Skip the first row from dataset

df_fdnc = pd.read_csv('FDNY.csv', skiprows=1)

# %%
# View the first five records from fixid dataset
df_fdnc.head()
# Out:
#                                         FacilityName        FacilityAddress  \
# 0                                 Engine 4/Ladder 15        42 South Street
# 1                                Engine 10/Ladder 10     124 Liberty Street
# 2                                           Engine 6      49 Beekman Street
# 3  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...   100-104 Duane Street
# 4                                           Ladder 8  14 North Moore Street
#
#      Borough
# 0  Manhattan
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
# View the data statistics using the descripe()
df_fdnc.describe()
# Out:
#               FacilityName  FacilityAddress   Borough
# count                  218              218       218
# unique                 218              218         5
# top     Engine 4/Ladder 15  42 South Street  Brooklyn
# freq                     1                1        66

# %%
# View the columns of dataset

df_fdnc.columns
# Out:
# Index(['FacilityName', 'FacilityAddress', 'Borough'], dtype='object')

# %%
# View the index of dataset

df_fdnc.index
# Out:
# RangeIndex(start=0, stop=218, step=1)

# %%
# Count the number of records

df_fdnc.count()
# Out:
# FacilityName       218
# FacilityAddress    218
# Borough            218
# dtype: int64

# %%
# View dayatype
df_fdnc.dtypes
# Out:
# FacilityName       object
# FacilityAddress    object
# Borough            object
# dtype: object

# %%
# Select FDNY informtion boroughwise
groupby_borough = df_fdnc.groupby('Borough')

# %%
groupby_borough.size()
# Out:
# Borough
# Bronx            34
# Brooklyn         66
# Manhattan        48
# Queens           50
# Staten Island    20
# dtype: int64

# %%
# View FDNY information for each borogh

# %%
# Select FDNY information for Manhatan

fdnc_infoManhatan = groupby_borough.get_group('Manhattan')

# %%
# Veiw FDNY information for Manhatan

fdnc_infoManhatan
# Out:
#                                          FacilityName  \
# 0                                  Engine 4/Ladder 15
# 1                                 Engine 10/Ladder 10
# 2                                            Engine 6
# 3   Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                            Ladder 8
# 5                                   Engine 9/Ladder 6
# 6                     Engine 15/Ladder 18/Battalion 4
# 7                                 Engine 28/Ladder 11
# 8                                            Engine 5
# 9                                           Engine 55
# 10                               Ladder 20/Division 1
# 11                     Engine 24/Ladder 5/Battalion 2
# 12                                 Engine 33/Ladder 9
# 13                               Ladder 3/Battalion 6
# 14                                           Squad 18
# 15                                Engine 34/Ladder 21
# ...
