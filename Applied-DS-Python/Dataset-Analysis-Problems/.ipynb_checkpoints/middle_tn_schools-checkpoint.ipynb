# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# <h4>You are a public-school administrator. Some schools in your state of Tennessee are</h4>
# <p>performing below average academically. Your superintendent seems to be under
# pressure from frustrated parents and the voters have appoached you with the task of
# finding out why these schools are underperforming.
# Now, to improve school performance, you need to learn more about these schools
# and their students, just as a business needs to understand its own strengths and
# weaknesses and its customers. The data includes various demographics, the school
# faculty, and income variables.</p>
# <ul>This can be achieved using exploratory data analysis techniques which further
# include:
# </ul>
# <li>Reading the data in pandas data frame</li>
# <li>Describing the data to find more details</li>
# <li>Finding the correlation between 'reduced lunch' and 'school rating'</li>

# %%
# Importing the necessary libraries

import pandas as pd
import os

os.getcwd()
os.chdir('/Users/laythal-shblawi/Desktop/Post-Graduate-Data-Science\
/Applied-DS-Python/Dataset-Analysis-Problems/Datasets')

# %%
# Reading the csv file

df = pd.read_csv('middle_tn_schools.csv')
df
# Out:
#                              name  school_rating   size  reduced_lunch  \
# 0     Allendale Elementary School            5.0  851.0           10.0
# 1             Anderson Elementary            2.0  412.0           71.0
# 2                Avoca Elementary            4.0  482.0           43.0
# 3                   Bailey Middle            0.0  394.0           91.0
# 4             Barfield Elementary            4.0  948.0           26.0
# ..                            ...            ...    ...            ...
# 342  Winfree Bryant Middle School            3.0  611.0           57.0
# 343    Winstead Elementary School            5.0  515.0            8.0
# 344           Woodland Elementary            4.0  424.0           55.0
# 345        Woodland Middle School            5.0  866.0            2.0
# 346                 Wright Middle            0.0  829.0           89.0
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
# Checking dataset the shape and details
df.shape
df.describe()
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# ...

# %%
df[['school_rating','reduced_lunch']].\
groupby(['school_rating']).describe().unstack()
# Out:
#                       school_rating
# reduced_lunch  count  0.0              43.000000
#                       1.0              40.000000
#                       2.0              44.000000
#                       3.0              56.000000
#                       4.0              86.000000
#                       5.0              78.000000
#                mean   0.0              83.581395
#                       1.0              74.950000
#                       2.0              64.272727
#                       3.0              50.285714
#                       4.0              41.000000
#                       5.0              21.602564
#                std    0.0               8.813498
#                       1.0              11.644191
#                       2.0              11.956051
#                       3.0              13.550866
#                       4.0              16.681092
#                       5.0              17.651268
# ...

# %%
# Finding the correlation between 'reduced lunch' and 'school rating'
df[['school_rating','reduced_lunch']].corr()
# Out:
#                school_rating  reduced_lunch
# school_rating       1.000000      -0.815757
# reduced_lunch      -0.815757       1.000000
